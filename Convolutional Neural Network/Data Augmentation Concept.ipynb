# %%
from torchvision import transforms
from luwiji.cnn import illustration

# %% [markdown]
# # Data Augmentation
#
# Augmentasi : Sedikit mengubah data asli / di edit sedikit
#
# - Meningkatkan generality (mengurangi overfit)
# - menambah data

# %%
img = illustration.img
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=386x288 at 0x1E0DC323308>

# %% [markdown]
# ### Random Crop

# %%
crop = transforms.RandomCrop(256)
crop(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=256x256 at 0x1E0E0853C08>

# %% [markdown]
# ### Random Flip

# %%
hflip = transforms.RandomHorizontalFlip()
hflip(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x1E0E08FD3C8>

# %%
vflip = transforms.RandomVerticalFlip()
vflip(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x1E0E07AD1C8>

# %% [markdown]
# ### Random Rotation

# %%
rotate = transforms.RandomRotation(10)
rotate(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x1E0E08B22C8>

# %% [markdown]
# ### Random ResizedCrop

# %%
resize = transforms.RandomResizedCrop(256, scale=(0.3, 1.0))
resize(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=256x256 at 0x1E0E0D913C8>

# %% [markdown]
# ### Random Affine (Translasi)

# %%
translate = transforms.RandomAffine(0, translate=(0.3, 0.3))
translate(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x1E0E07CF588>

# %%
shear = transforms.RandomAffine(0, shear=10)
shear(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x1E0E0A0FB48>

# %%
affine = transforms.RandomAffine(5, translate=(0.1, 0.1), shear=10)
affine(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x1E0E0C85C48>

# %% [markdown]
# ### Color Jitter

# %%
brightness = transforms.ColorJitter(brightness=0.3)
brightness(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x1E0E0A14708>

# %%
contrast = transforms.ColorJitter(contrast=0.3)
contrast(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=386x288 at 0x1E0E096AF08>
